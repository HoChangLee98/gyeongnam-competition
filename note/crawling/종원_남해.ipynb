# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
busroute_usage = pd.read_csv(
    filepath_or_buffer="../data/gyeongn_busroute_total.csv"
    )

# %%
# Out:
# 138

# %%
import pickle
with open("../data/버스이용데이터/창원시_usage.pkl", "rb") as f:
    창원시_usage =  pickle.load(f)

# %%
창원시_usage["창원시"]["2"] = 2558
창원시_usage["창원시"]["3"] = 299
창원시_usage["창원시"]["8"] = 68306
창원시_usage["창원시"]["13"] = 4501
창원시_usage["창원시"]["50"] = 5177
창원시_usage["창원시"]["60"] = 3672
창원시_usage["창원시"]["61"] = 2982
창원시_usage["창원시"]["109"] = 168472
창원시_usage["창원시"]["260-2"] = 30470
창원시_usage["창원시"]["510"] = None
창원시_usage["창원시"]["510-1"] = None
창원시_usage["창원시"]["511"] = None
창원시_usage["창원시"]["511-1"] = None
창원시_usage["창원시"]["530"] = None
창원시_usage["창원시"]["530-1"] = None
창원시_usage["창원시"]["540"] = None
창원시_usage["창원시"]["3005"] = 549
창원시_usage["창원시"]["3005-9"] = 549
창원시_usage["창원시"]["BRT일반(5000)"] = 13562
창원시_usage["창원시"]["BRT급행(6000)"] = 96263
창원시_usage["창원시"]["65-2"] = 11696
창원시_usage["창원시"]["258-9"] = 6275

# %%
창원시_usage
# Out:
# {'창원시': {'1': 33931,
#   '2': 2558,
#   '3': 299,
#   '7': 63612,
#   '8': 68306,
#   '10': 20688,
#   '11': 2024,
#   '12': 11121,
#   '13': 4501,
#   '14': 4389,
#   '15': 1849,
#   '17': 94109,
#   '19': 7820,
#   '20': 51104,
#   '21': 5787,
#   '22': 16043,
#   '23': 6680,
#   '24': 29985,
#   '27': 120052,
#   '30': 10551,
#   '31': 4144,
#   '32': 9474,
#   '33': 1663,
#   '34': 5561,
#   '35': 5835,
#   '36': 1872,
#   '37': 1032,
#   '40': 10333,
#   '41': 5222,
#   '42': 6658,
#   '44': 5355,
#   '45': 6874,
#   '46': 4807,
#   '49': 3175,
#   '50': 5177,
#   '51': 17827,
#   '53': 9098,
#   '54': 4164,
#   '55': 1232,
#   '60': 3672,
#   '61': 2982,
#   '61-1': 2982,
#   '62': 15196,
#   '64': 2141,
#   '73-1': 1049,
#   '74': 6974,
#   '74-1': 2331,
#   '75': 5175,
#   '75-1': 1788,
#   '75-2': 989,
#   '76': 5916,
#   '77': 4473,
#   '77-1': 1975,
#   '64-1': 3891,
#   '65': 13856,
#   '65-2': 11696,
#   '65-1': 11696,
#   '70': 36068,
#   '71': 31100,
#   '72': 10159,
# ...

# %%
# with open(f'../data/버스이용데이터/창원시_usage.pkl', 'wb') as f: 
# 	pickle.dump(창원시_usage, f)

# %%
with open("../data/버스이용데이터/창원시_usage.pkl", "rb") as f:
    창원시_usage =  pickle.load(f)

# %%
창원시_usage
# Out:
# {'창원시': {'1': 33931,
#   '2': 2558,
#   '3': 299,
#   '7': 63612,
#   '8': 68306,
#   '10': 20688,
#   '11': 2024,
#   '12': 11121,
#   '13': 4501,
#   '14': 4389,
#   '15': 1849,
#   '17': 94109,
#   '19': 7820,
#   '20': 51104,
#   '21': 5787,
#   '22': 16043,
#   '23': 6680,
#   '24': 29985,
#   '27': 120052,
#   '30': 10551,
#   '31': 4144,
#   '32': 9474,
#   '33': 1663,
#   '34': 5561,
#   '35': 5835,
#   '36': 1872,
#   '37': 1032,
#   '40': 10333,
#   '41': 5222,
#   '42': 6658,
#   '44': 5355,
#   '45': 6874,
#   '46': 4807,
#   '49': 3175,
#   '50': 5177,
#   '51': 17827,
#   '53': 9098,
#   '54': 4164,
#   '55': 1232,
#   '60': 3672,
#   '61': 2982,
#   '61-1': 2982,
#   '62': 15196,
#   '64': 2141,
#   '73-1': 1049,
#   '74': 6974,
#   '74-1': 2331,
#   '75': 5175,
#   '75-1': 1788,
#   '75-2': 989,
#   '76': 5916,
#   '77': 4473,
#   '77-1': 1975,
#   '64-1': 3891,
#   '65': 13856,
#   '65-2': 11696,
#   '65-1': 11696,
#   '70': 36068,
#   '71': 31100,
#   '72': 10159,
# ...
