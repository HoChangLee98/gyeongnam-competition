# %% [markdown]
# ## 함안군 노가다

# %%
import pandas as pd
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
# # 데이터 로드
with open('../data/버스정보데이터/함안군_inform.pkl', 'rb') as f:
	data = pickle.load(f)

# %%
data
# Out:
# {'함안군': {'777-10': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '777-2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '777-11': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '777-20': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '777-22': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '777-21': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '72-4': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '72-5': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-16': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-10': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-90': {'노선정류장수': 38, '노선거리(km)': 41.7, '굴곡도': 1.3},
#   '1-11': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '72-2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-21': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-22': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
#   '1-12': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
# ...

# %%
data = {'함안군': {'777-10': {'노선정류장수': 21, '노선거리(km)': None, '굴곡도': None},
  '777-2': {'노선정류장수': 42, '노선거리(km)': None, '굴곡도': None},
  '777-11': {'노선정류장수': 22, '노선거리(km)': None, '굴곡도': None},
  '777-20': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '777-22': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '777-21': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '72-4': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '72-5': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '1-16': {'노선정류장수': 16, '노선거리(km)': None, '굴곡도': None},
  '1-10': {'노선정류장수': 26, '노선거리(km)': None, '굴곡도': None},
  '1-90': {'노선정류장수': 38, '노선거리(km)': 41.7, '굴곡도': 1.3},
  '1-11': {'노선정류장수': 49, '노선거리(km)': None, '굴곡도': None},
  '72-2': {'노선정류장수': 43, '노선거리(km)': None, '굴곡도': None},
  '1-21': {'노선정류장수': 32, '노선거리(km)': None, '굴곡도': None},
  '1-22': {'노선정류장수': 30, '노선거리(km)': None, '굴곡도': None},
  '1-12': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
  '1-14': {'노선정류장수': 30, '노선거리(km)': None, '굴곡도': None},
  '1-13': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '1-91': {'노선정류장수': 10, '노선거리(km)': None, '굴곡도': None},
  '1-15': {'노선정류장수': 49, '노선거리(km)': None, '굴곡도': None},
  '1-30': {'노선정류장수': 10, '노선거리(km)': None, '굴곡도': None},
  '1-31': {'노선정류장수': 21, '노선거리(km)': None, '굴곡도': None},
  '1-32': {'노선정류장수': 28, '노선거리(km)': None, '굴곡도': None},
  '250-10': {'노선정류장수': 59, '노선거리(km)': None, '굴곡도': None},
  '252-23': {'노선정류장수': 78, '노선거리(km)': None, '굴곡도': None},
  '252-20': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': None},
  '252-24': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
  '1-40': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '252-21': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '250-20': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': None},
  '250-30': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '250-23': {'노선정류장수': 78, '노선거리(km)': None, '굴곡도': None},
  '252-31': {'노선정류장수': 73, '노선거리(km)': None, '굴곡도': None},
  '252-32': {'노선정류장수': 73, '노선거리(km)': None, '굴곡도': None},
  '1-50': {'노선정류장수': 34, '노선거리(km)': None, '굴곡도': None},
  '113-31': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
  '113-05': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '113-74': {'노선정류장수': 67, '노선거리(km)': None, '굴곡도': None},
  '113-01': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '113-08': {'노선정류장수': 42, '노선거리(km)': None, '굴곡도': None},
  '113-10': {'노선정류장수': 38, '노선거리(km)': 41.7, '굴곡도': 1.3},
  '113-38': {'노선정류장수': 81, '노선거리(km)': None, '굴곡도': None},
  '113-39': {'노선정류장수': 94, '노선거리(km)': 55.8, '굴곡도': 1.5},
  '113-57': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '1-60': {'노선정류장수': 15, '노선거리(km)': None, '굴곡도': None},
  '113-60': {'노선정류장수': 60, '노선거리(km)': None, '굴곡도': None},
  '113-84': {'노선정류장수': 48, '노선거리(km)': None, '굴곡도': None},
  '113-59': {'노선정류장수': 96, '노선거리(km)': 56.8, '굴곡도': 1.5},
  '113-81': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '113-35': {'노선정류장수': 117, '노선거리(km)': 80.9, '굴곡도': 1.7},
  '113-71': {'노선정류장수': 99, '노선거리(km)': 65.3, '굴곡도': 1.8},
  '113-52': {'노선정류장수': 47, '노선거리(km)': None, '굴곡도': None},
  '113-41': {'노선정류장수': 98, '노선거리(km)': 59.7, '굴곡도': 1.8},
  '113-29': {'노선정류장수': 98, '노선거리(km)': 59.7, '굴곡도': 1.8},
  '1-70': {'노선정류장수': 22, '노선거리(km)': None, '굴곡도': None},
  '1-71': {'노선정류장수': 27, '노선거리(km)': None, '굴곡도': None},
  '1-72': {'노선정류장수': 28, '노선거리(km)': None, '굴곡도': None},
  '1-73': {'노선정류장수': 28, '노선거리(km)': None, '굴곡도': None},
  '113-22': {'노선정류장수': 61, '노선거리(km)': None, '굴곡도': None},
  '113-36': {'노선정류장수': 60, '노선거리(km)': None, '굴곡도': None},
  '113-34': {'노선정류장수': 55, '노선거리(km)': None, '굴곡도': None},
  '113-83': {'노선정류장수': 52, '노선거리(km)': None, '굴곡도': None},
  '1-80': {'노선정류장수': 18, '노선거리(km)': None, '굴곡도': None},
  '113-51': {'노선정류장수': 51, '노선거리(km)': None, '굴곡도': None},
  '113-26': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '113-21': {'노선정류장수': 113, '노선거리(km)': 80.4, '굴곡도': 1.7},
  '113-04': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '113-23': {'노선정류장수': 126, '노선거리(km)': 78.6, '굴곡도': 1.9},
  '113-25': {'노선정류장수': 126, '노선거리(km)': 77.9, '굴곡도': 1.8},
  '113-58': {'노선정류장수': 48, '노선거리(km)': None, '굴곡도': None},
  '113-72': {'노선정류장수': 68, '노선거리(km)': None, '굴곡도': None},
  '113-24': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '113-32': {'노선정류장수': 68, '노선거리(km)': None, '굴곡도': None},
  '113-27': {'노선정류장수': 113, '노선거리(km)': 58.5, '굴곡도': 2.1},
  '113-30': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
  '113-54': {'노선정류장수': 59, '노선거리(km)': None, '굴곡도': None},
  '113-56': {'노선정류장수': 49, '노선거리(km)': None, '굴곡도': None},
  '113-79': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '113-75': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
  '113-50': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '113-37': {'노선정류장수': 86, '노선거리(km)': None, '굴곡도': None},
  '113-82': {'노선정류장수': 59, '노선거리(km)': None, '굴곡도': None},
  '113-70': {'노선정류장수': 60, '노선거리(km)': None, '굴곡도': None},
  '113-33': {'노선정류장수': 65, '노선거리(km)': 32.8, '굴곡도': 2.1},
  '113-28': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '114-21': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '114-22': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '113-55': {'노선정류장수': 93, '노선거리(km)': 57.6, '굴곡도': 3.7},
  '113-53': {'노선정류장수': 99, '노선거리(km)': 55.3, '굴곡도': 1.7},
  '113-78': {'노선정류장수': 69, '노선거리(km)': None, '굴곡도': None},
  '113-02': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '113-07': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '113-09': {'노선정류장수': 43, '노선거리(km)': None, '굴곡도': None},
  '113-03': {'노선정류장수': 54, '노선거리(km)': None, '굴곡도': None},
  '113-73': {'노선정류장수': 93, '노선거리(km)': 63.5, '굴곡도': 1.8},
  '114-23': {'노선정류장수': 53, '노선거리(km)': None, '굴곡도': None},
  '114-13': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '114-11': {'노선정류장수': 45, '노선거리(km)': None, '굴곡도': None},
  '113-80': {'노선정류장수': 72, '노선거리(km)': None, '굴곡도': None},
  '113-77': {'노선정류장수': 110, '노선거리(km)': 69.9, '굴곡도': 2.6},
  '114-14': {'노선정류장수': 54, '노선거리(km)': None, '굴곡도': None},
  '114-20': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '114-10': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '114-12': {'노선정류장수': 59, '노선거리(km)': None, '굴곡도': None},
  '114-15': {'노선정류장수': 59, '노선거리(km)': None, '굴곡도': None},
  '114-16': {'노선정류장수': 55, '노선거리(km)': None, '굴곡도': None},
  '113-40': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': None},
  '113-06': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '1-20': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
  '777-48': {'노선정류장수': 22, '노선거리(km)': None, '굴곡도': None},
  '777-41': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '777-42': {'노선정류장수': 39, '노선거리(km)': None, '굴곡도': None},
  '777-45': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '777-46': {'노선정류장수': 46, '노선거리(km)': None, '굴곡도': None},
  '777-52': {'노선정류장수': 42, '노선거리(km)': None, '굴곡도': None},
  '250-40': {'노선정류장수': 101, '노선거리(km)': None, '굴곡도': None},
  '250-41': {'노선정류장수': 71, '노선거리(km)': None, '굴곡도': None},
  '250-22': {'노선정류장수': 72, '노선거리(km)': None, '굴곡도': None},
  '252-30': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '250-21': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '777-50': {'노선정류장수': 11, '노선거리(km)': None, '굴곡도': None},
  '777-40': {'노선정류장수': 32, '노선거리(km)': None, '굴곡도': None},
  '72-3': {'노선정류장수': 47, '노선거리(km)': None, '굴곡도': None},
  '777-47': {'노선정류장수': 22, '노선거리(km)': None, '굴곡도': None},
  '1-75': {'노선정류장수': 20, '노선거리(km)': None, '굴곡도': None},
  '777-43': {'노선정류장수': 32, '노선거리(km)': None, '굴곡도': None},
  '1-17': {'노선정류장수': 9, '노선거리(km)': None, '굴곡도': None},
  '1-77': {'노선정류장수': 24, '노선거리(km)': None, '굴곡도': None},
  '1-76': {'노선정류장수': 21, '노선거리(km)': None, '굴곡도': None},
  '777-30': {'노선정류장수': 51, '노선거리(km)': None, '굴곡도': None},
  '777-31': {'노선정류장수': 39, '노선거리(km)': None, '굴곡도': None},
  '113-76': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '113-11': {'노선정류장수': 113, '노선거리(km)': 65.1, '굴곡도': 1.6},
  '3': {'노선정류장수': 34, '노선거리(km)': None, '굴곡도': None},
  '1': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '2': {'노선정류장수': 76, '노선거리(km)': None, '굴곡도': None}}}

# %%
import pickle

with open(f'../data/버스정보데이터/함안군_inform.pkl', 'wb') as f: 
	pickle.dump(data, f)
