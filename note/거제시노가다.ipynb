# %% [markdown]
# ## 거제시 노가다

# %%
import pandas as pd
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
# # 데이터 로드
with open('../data/버스정보데이터/거제시_inform.pkl', 'rb') as f:
	data = pickle.load(f)

# %%
data
# Out:
# {'거제시': {'10': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
#   '11': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
#   '11-2': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
#   '22': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
#   '23': {'노선정류장수': 48, '노선거리(km)': None, '굴곡도': None},
#   '22-1': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
#   '23-1': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
#   '20(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
#   '24-1': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
#   '40(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
#   '40-1': {'노선정류장수': 33, '노선거리(km)': None, '굴곡도': None},
#   '40-2': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
#   '40-3': {'노선정류장수': 35, '노선거리(km)': None, '굴곡도': None},
#   '41': {'노선정류장수': 61, '노선거리(km)': None, '굴곡도': None},
#   '41-1': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
#   '41-2': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
#   '42': {'노선정류장수': 65, '노선거리(km)': None, '굴곡도': None},
# ...

# %%
data = {'거제시': {'10': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '11': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '11-2': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '22': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '23': {'노선정류장수': 48, '노선거리(km)': None, '굴곡도': None},
  '22-1': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '23-1': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '20(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
  '24-1': {'노선정류장수': 58, '노선거리(km)': None, '굴곡도': None},
  '40(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
  '40-1': {'노선정류장수': 33, '노선거리(km)': None, '굴곡도': None},
  '40-2': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '40-3': {'노선정류장수': 35, '노선거리(km)': None, '굴곡도': None},
  '41': {'노선정류장수': 61, '노선거리(km)': None, '굴곡도': None},
  '41-1': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
  '41-2': {'노선정류장수': 64, '노선거리(km)': None, '굴곡도': None},
  '42': {'노선정류장수': 65, '노선거리(km)': None, '굴곡도': None},
  '42-2': {'노선정류장수': 71, '노선거리(km)': None, '굴곡도': None},
  '58(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
  '50': {'노선정류장수': 34, '노선거리(km)': None, '굴곡도': None},
  '55': {'노선정류장수': 43, '노선거리(km)': None, '굴곡도': None},
  '51': {'노선정류장수': 43, '노선거리(km)': None, '굴곡도': None},
  '52(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
  '53': {'노선정류장수': 56, '노선거리(km)': None, '굴곡도': None},
  '53-1': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '54': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '44(상)': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': 1.7},
  '70': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '130': {'노선정류장수': 29, '노선거리(km)': None, '굴곡도': None},
  '71': {'노선정류장수': 75, '노선거리(km)': None, '굴곡도': None},
  '71-1': {'노선정류장수': 76, '노선거리(km)': None, '굴곡도': None},
  '통학2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '131': {'노선정류장수': 45, '노선거리(km)': None, '굴곡도': None},
  '131-1': {'노선정류장수': 41, '노선거리(km)': None, '굴곡도': None},
  '113': {'노선정류장수': 41, '노선거리(km)': 14.3, '굴곡도': 1.3},
  '39': {'노선정류장수': 43, '노선거리(km)': None, '굴곡도': None},
  '38': {'노선정류장수': 41, '노선거리(km)': None, '굴곡도': None},
  '35': {'노선정류장수': 78, '노선거리(km)': None, '굴곡도': None},
  '35-1': {'노선정류장수': 79, '노선거리(km)': None, '굴곡도': None},
  '37': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '36': {'노선정류장수': 66, '노선거리(km)': None, '굴곡도': None},
  '36-1': {'노선정류장수': 29, '노선거리(km)': None, '굴곡도': None},
  '30-1': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '31-1': {'노선정류장수': 95, '노선거리(km)': None, '굴곡도': None},
  '31': {'노선정류장수': 95, '노선거리(km)': None, '굴곡도': None},
  '30': {'노선정류장수': 96, '노선거리(km)': None, '굴곡도': None},
  '33(상)': {'노선정류장수': 41, '노선거리(km)': 14.3, '굴곡도': 1.3},
  '32': {'노선정류장수': 85, '노선거리(km)': None, '굴곡도': None},
  '34': {'노선정류장수': 49, '노선거리(km)': None, '굴곡도': None},
  '61': {'노선정류장수': 29, '노선거리(km)': None, '굴곡도': None},
  '61-1': {'노선정류장수': 30, '노선거리(km)': None, '굴곡도': None},
  '62': {'노선정류장수': 31, '노선거리(km)': None, '굴곡도': None},
  '62-1': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '63': {'노선정류장수': 40, '노선거리(km)': None, '굴곡도': None},
  '67': {'노선정류장수': 80, '노선거리(km)': None, '굴곡도': None},
  '65': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '60': {'노선정류장수': 28, '노선거리(km)': None, '굴곡도': None},
  '60-1': {'노선정류장수': 29, '노선거리(km)': None, '굴곡도': None},
  '17-1': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '17': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '100': {'노선정류장수': 43, '노선거리(km)': 15.2, '굴곡도': 3.2},
  '101': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '110': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '111': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '100-2': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '112': {'노선정류장수': 13, '노선거리(km)': None, '굴곡도': None},
  '130-2': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '114': {'노선정류장수': 23, '노선거리(km)': None, '굴곡도': None},
  '102': {'노선정류장수': 130, '노선거리(km)': None, '굴곡도': None},
  '120': {'노선정류장수': 47, '노선거리(km)': None, '굴곡도': None},
  '43': {'노선정류장수': 69, '노선거리(km)': None, '굴곡도': None},
  '43-1': {'노선정류장수': 65, '노선거리(km)': None, '굴곡도': None},
  '120-1': {'노선정류장수': 50, '노선거리(km)': None, '굴곡도': None},
  '54-1': {'노선정류장수': 54, '노선거리(km)': None, '굴곡도': None},
  '116': {'노선정류장수': 34, '노선거리(km)': None, '굴곡도': None},
  '104': {'노선정류장수': 65, '노선거리(km)': None, '굴곡도': None},
  '103': {'노선정류장수': 22, '노선거리(km)': None, '굴곡도': None},
  '16': {'노선정류장수': 75, '노선거리(km)': None, '굴곡도': None},
  '16-1': {'노선정류장수': 84, '노선거리(km)': None, '굴곡도': None},
  '16-2': {'노선정류장수': 74, '노선거리(km)': None, '굴곡도': None},
  '150': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '152': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '16-4': {'노선정류장수': 70, '노선거리(km)': None, '굴곡도': None},
  '20-1': {'노선정류장수': 53, '노선거리(km)': None, '굴곡도': None},
  '140': {'노선정류장수': 41, '노선거리(km)': None, '굴곡도': None},
  '141': {'노선정류장수': 44, '노선거리(km)': None, '굴곡도': None},
  '151': {'노선정류장수': 42, '노선거리(km)': None, '굴곡도': None},
  '통학7': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '120-2': {'노선정류장수': 53, '노선거리(km)': None, '굴곡도': None},
  '2000(상)': {'노선정류장수': 43, '노선거리(km)': 15.2, '굴곡도': 3.2},
  '14': {'노선정류장수': 35, '노선거리(km)': None, '굴곡도': None},
  '10-3': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '10-2': {'노선정류장수': 23, '노선거리(km)': None, '굴곡도': None},
  '16-3': {'노선정류장수': 82, '노선거리(km)': None, '굴곡도': None},
  '20-2': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '32-1': {'노선정류장수': 88, '노선거리(km)': None, '굴곡도': None},
  '55-1': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '300': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '310': {'노선정류장수': 18, '노선거리(km)': None, '굴곡도': None},
  '152-1': {'노선정류장수': 28, '노선거리(km)': None, '굴곡도': None},
  '33-1': {'노선정류장수': 90, '노선거리(km)': None, '굴곡도': None},
  '11-3': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '132': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '132-2': {'노선정류장수': 38, '노선거리(km)': None, '굴곡도': None},
  '132-6': {'노선정류장수': 46, '노선거리(km)': None, '굴곡도': None},
  '통학1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '134': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '301': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '133': {'노선정류장수': 34, '노선거리(km)': None, '굴곡도': None},
  '132-3': {'노선정류장수': 37, '노선거리(km)': None, '굴곡도': None},
  '132-4': {'노선정류장수': 47, '노선거리(km)': None, '굴곡도': None},
  '3000': {'노선정류장수': 24, '노선거리(km)': None, '굴곡도': None},
  '4000': {'노선정류장수': 23, '노선거리(km)': None, '굴곡도': None},
  '25': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '25-1': {'노선정류장수': 55, '노선거리(km)': None, '굴곡도': None},
  '16-5': {'노선정류장수': 63, '노선거리(km)': None, '굴곡도': None},
  '12-1': {'노선정류장수': 42, '노선거리(km)': None, '굴곡도': None},
  '14-1': {'노선정류장수': 39, '노선거리(km)': None, '굴곡도': None},
  '24-2': {'노선정류장수': 47, '노선거리(km)': None, '굴곡도': None},
  '25-2': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '30-2': {'노선정류장수': 63, '노선거리(km)': None, '굴곡도': None},
  '67-1': {'노선정류장수': 95, '노선거리(km)': None, '굴곡도': None},
  '152-2': {'노선정류장수': 24, '노선거리(km)': None, '굴곡도': None},
  '통학1-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '132-7': {'노선정류장수': 46, '노선거리(km)': None, '굴곡도': None},
  '통학3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '통학4': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '통학5': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '통학6': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '통학8': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '50-2': {'노선정류장수': 36, '노선거리(km)': None, '굴곡도': None},
  '통학10': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '통학9': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '25-3': {'노선정류장수': 57, '노선거리(km)': None, '굴곡도': None},
  '통학2-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제5': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제1-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제2-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제2-2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제3-3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제3-2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제3-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-4': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-5': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '거제4-6': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '둔덕1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '둔덕2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '남부3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '남부2': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '남부4': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '남부1': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None},
  '둔덕3': {'노선정류장수': None, '노선거리(km)': None, '굴곡도': None}}}

# %%
import pickle

with open(f'../data/버스정보데이터/거제시_inform.pkl', 'wb') as f: 
	pickle.dump(data, f)
