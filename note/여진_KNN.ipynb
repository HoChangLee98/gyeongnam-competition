# %% [markdown]
# ## 추가 변수 생성 및 결측치 처리

# %%
import pandas as pd
import numpy as np
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
## total_busdata 
total = pd.read_csv(
    filepath_or_buffer="../data/여진_total_busdata.csv"
    )

# %% [markdown]
# ## KNN algorithm

# %%
sc = total[total['city_name']=='사천시']

# %%
df = sc[['startvehicletime', 'endvehicletime', 'intervaltime','intervalsattime',
'intervalsuntime','usage','노선정류장수','노선거리(km)','굴곡도', 'num_bus']]

original_df = df.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 680 to 739
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   startvehicletime  60 non-null     float64
#  1   endvehicletime    60 non-null     float64
#  2   intervaltime      60 non-null     float64
#  3   intervalsattime   60 non-null     float64
#  4   intervalsuntime   60 non-null     float64
#  5   usage             59 non-null     float64
#  6   노선정류장수            60 non-null     int64
#  7   노선거리(km)          60 non-null     float64
#  8   굴곡도               60 non-null     float64
#  9   num_bus           60 non-null     int64
# dtypes: float64(8), int64(2)
# memory usage: 5.2 KB

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=3)
imputed = imputer.fit_transform(df)
df_imputed = pd.DataFrame(imputed, columns=df.columns)
df_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   startvehicletime  60 non-null     float64
#  1   endvehicletime    60 non-null     float64
#  2   intervaltime      60 non-null     float64
#  3   intervalsattime   60 non-null     float64
#  4   intervalsuntime   60 non-null     float64
#  5   usage             60 non-null     float64
#  6   노선정류장수            60 non-null     float64
#  7   노선거리(km)          60 non-null     float64
#  8   굴곡도               60 non-null     float64
#  9   num_bus           60 non-null     float64
# dtypes: float64(10)
# memory usage: 4.8 KB

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(original_df, df_imputed)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 mse = mean_squared_error(original_df, df_imputed)
#       3 print(mse)
#
# File c:\Users\jihoo\anaconda3\envs\gyeongn\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %%
list(df_imputed['usage'])
# Out:
# [33931.0,
#  2558.0,
#  299.0,
#  63612.0,
#  68306.0,
#  20688.0,
#  2024.0,
#  11121.0,
#  4501.0,
#  4389.0,
#  1849.0,
#  94109.0,
#  7820.0,
#  51104.0,
#  5787.0,
#  16043.0,
#  6680.0,
#  29985.0,
#  120052.0,
#  10551.0,
#  4144.0,
#  9474.0,
#  1663.0,
#  5561.0,
#  5835.0,
#  1872.0,
#  1032.0,
#  10333.0,
#  5222.0,
#  6658.0,
#  5355.0,
#  6874.0,
#  4807.0,
#  3175.0,
#  5177.0,
#  17827.0,
#  9098.0,
#  4164.0,
#  1232.0,
#  3672.0,
#  2982.0,
#  2982.0,
#  15196.0,
#  2141.0,
#  1049.0,
#  6974.0,
#  2331.0,
#  5175.0,
#  1788.0,
#  989.0,
#  5916.0,
#  4473.0,
#  1975.0,
#  3891.0,
#  13856.0,
#  11696.0,
#  11696.0,
#  36068.0,
#  31100.0,
#  10159.0,
#  1960.0,
#  12201.0,
#  5730.0,
#  29095.0,
#  253220.0,
#  131093.0,
#  167730.0,
#  335737.0,
#  220604.0,
#  115456.0,
#  103106.0,
#  138892.0,
#  168472.0,
#  89811.0,
#  89207.0,
#  186661.0,
#  45694.0,
#  146843.0,
#  74133.0,
#  170594.0,
#  31407.0,
#  96230.0,
#  17683.0,
#  130050.0,
#  57674.0,
# ...

# %%
#from impyute.imputation.cs import fast_knn

#np_imputed = fast_knn(df.values, k=5)
#df_imputed = pd.DataFrame(np_imputed)
