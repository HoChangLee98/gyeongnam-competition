# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import geopandas as gpd
import glob
import os
from shapely.geometry import Polygon
from shapely.geometry import Point

# %%
# Shapefile 파일이 있는 디렉토리 경로
directory_path = "../data/경남 노인 인구 분포/"

# Shapefile 파일 경로를 모두 가져오기
shapefile_paths = glob.glob(os.path.join(directory_path, "**/*.shp"))

gdfs = []

# 각 Shapefile을 읽어 리스트에 추가
for shapefile in shapefile_paths:
    gdf = gpd.read_file(shapefile, encoding="utf-8")
    gdfs.append(gdf)

# 모든 GeoDataFrame을 하나로 병합
merged_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))


merged_gdf['val'] = merged_gdf['val'].fillna(0)
merged_gdf = merged_gdf[merged_gdf["val"].apply(lambda x: x != 0.0)]
merged_gdf = merged_gdf.to_crs(epsg=5179)

# %%
merged_gdf['point'] = merged_gdf['geometry'].centroid.apply(lambda centroid: Point(centroid.x, centroid.y))

# %%
merged_gdf
# Out:
#              gid    lbl   val  \
# 4       마라008419   7.00   7.0
# 6       마라044519  20.00  20.0
# 9       라라975559  26.00  26.0
# 10      마라087557  13.00  13.0
# 19      마라039555  15.00  15.0
# ...          ...    ...   ...
# 984274  라마600304  43.00  43.0
# 984277  라마664324   6.00   6.0
# 984279  라마710315   7.00   7.0
# 984280  라마565506   6.00   6.0
# 984282  라마751313   7.00   7.0
#
#                                                  geometry  \
# 4       POLYGON ((1100800 1641900, 1100800 1642000, 11...
# 6       POLYGON ((1104400 1651900, 1104400 1652000, 11...
# 9       POLYGON ((1097500 1655900, 1097500 1656000, 10...
# 10      POLYGON ((1108700 1655700, 1108700 1655800, 11...
# 19      POLYGON ((1103900 1655500, 1103900 1655600, 11...
# ...                                                   ...
# 984274  POLYGON ((1060000 1730400, 1060000 1730500, 10...
# 984277  POLYGON ((1066400 1732400, 1066400 1732500, 10...
# 984279  POLYGON ((1071000 1731500, 1071000 1731600, 10...
# 984280  POLYGON ((1056500 1750600, 1056500 1750700, 10...
# 984282  POLYGON ((1075100 1731300, 1075100 1731400, 10...
#
#                           point
# 4       POINT (1100850 1641950)
# 6       POINT (1104450 1651950)
# 9       POINT (1097550 1655950)
# 10      POINT (1108750 1655750)
# 19      POINT (1103950 1655550)
# ...                         ...
# 984274  POINT (1060050 1730450)
# 984277  POINT (1066450 1732450)
# 984279  POINT (1071050 1731550)
# 984280  POINT (1056550 1750650)
# 984282  POINT (1075150 1731350)
#
# [27538 rows x 5 columns]
